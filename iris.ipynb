# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
#import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
/kaggle/input/MMU-Iris-Database/ReadMe.txt
/kaggle/input/MMU-Iris-Database/1/left/aeval3.bmp
/kaggle/input/MMU-Iris-Database/1/left/aeval1.bmp
/kaggle/input/MMU-Iris-Database/1/left/aeval5.bmp
/kaggle/input/MMU-Iris-Database/1/left/aeval4.bmp
/kaggle/input/MMU-Iris-Database/1/left/Thumbs.db
/kaggle/input/MMU-Iris-Database/1/left/aeval2.bmp
/kaggle/input/MMU-Iris-Database/1/right/aevar1.bmp
/kaggle/input/MMU-Iris-Database/1/right/Thumbs.db
/kaggle/input/MMU-Iris-Database/1/right/aevar3.bmp
/kaggle/input/MMU-Iris-Database/1/right/aevar2.bmp
/kaggle/input/MMU-Iris-Database/1/right/aevar5.bmp
/kaggle/input/MMU-Iris-Database/1/right/aevar4.bmp
/kaggle/input/MMU-Iris-Database/19/left/maranl2.bmp
/kaggle/input/MMU-Iris-Database/19/left/maranl5.bmp
/kaggle/input/MMU-Iris-Database/19/left/maranl4.bmp
/kaggle/input/MMU-Iris-Database/19/left/maranl3.bmp
/kaggle/input/MMU-Iris-Database/19/left/maranl1.bmp
/kaggle/input/MMU-Iris-Database/19/right/maranr2.bmp
/kaggle/input/MMU-Iris-Database/19/right/maranr5.bmp
/kaggle/input/MMU-Iris-Database/19/right/maranr1.bmp
/kaggle/input/MMU-Iris-Database/19/right/maranr4.bmp
/kaggle/input/MMU-Iris-Database/19/right/maranr3.bmp
/kaggle/input/MMU-Iris-Database/33/left/sarinal3.bmp
/kaggle/input/MMU-Iris-Database/33/left/sarinal1.bmp
/kaggle/input/MMU-Iris-Database/33/left/sarinal5.bmp
/kaggle/input/MMU-Iris-Database/33/left/sarinal4.bmp
/kaggle/input/MMU-Iris-Database/33/left/sarinal2.bmp
/kaggle/input/MMU-Iris-Database/33/right/sarinar4.bmp
/kaggle/input/MMU-Iris-Database/33/right/sarinar2.bmp
/kaggle/input/MMU-Iris-Database/33/right/sarinar1.bmp
/kaggle/input/MMU-Iris-Database/33/right/sarinar3.bmp
/kaggle/input/MMU-Iris-Database/33/right/sarinar5.bmp
/kaggle/input/MMU-Iris-Database/28/left/ongbll1.bmp
/kaggle/input/MMU-Iris-Database/28/left/ongbll5.bmp
/kaggle/input/MMU-Iris-Database/28/left/ongbll2.bmp
/kaggle/input/MMU-Iris-Database/28/left/ongbll3.bmp
/kaggle/input/MMU-Iris-Database/28/left/ongbll4.bmp
/kaggle/input/MMU-Iris-Database/28/right/ongblr4.bmp
/kaggle/input/MMU-Iris-Database/28/right/ongblr3.bmp
/kaggle/input/MMU-Iris-Database/28/right/ongblr2.bmp
/kaggle/input/MMU-Iris-Database/28/right/ongblr5.bmp
/kaggle/input/MMU-Iris-Database/28/right/ongblr1.bmp
/kaggle/input/MMU-Iris-Database/12/left/kelvinl3.bmp
/kaggle/input/MMU-Iris-Database/12/left/kelvinl5.bmp
/kaggle/input/MMU-Iris-Database/12/left/kelvinl2.bmp
/kaggle/input/MMU-Iris-Database/12/left/kelvinl1.bmp
/kaggle/input/MMU-Iris-Database/12/left/kelvinl4.bmp
/kaggle/input/MMU-Iris-Database/12/right/kelvinr1.bmp
/kaggle/input/MMU-Iris-Database/12/right/kelvinr3.bmp
/kaggle/input/MMU-Iris-Database/12/right/kelvinr5.bmp
/kaggle/input/MMU-Iris-Database/12/right/kelvinr2.bmp
/kaggle/input/MMU-Iris-Database/12/right/kelvinr4.bmp
/kaggle/input/MMU-Iris-Database/39/left/tingcyl4.bmp
/kaggle/input/MMU-Iris-Database/39/left/tingcyl5.bmp
/kaggle/input/MMU-Iris-Database/39/left/tingcyl1.bmp
/kaggle/input/MMU-Iris-Database/39/left/tingcyl3.bmp
/kaggle/input/MMU-Iris-Database/39/left/tingcyl2.bmp
/kaggle/input/MMU-Iris-Database/39/right/tingcyr3.bmp
/kaggle/input/MMU-Iris-Database/39/right/tingcyr2.bmp
/kaggle/input/MMU-Iris-Database/39/right/tingcyr5.bmp
/kaggle/input/MMU-Iris-Database/39/right/tingcyr1.bmp
/kaggle/input/MMU-Iris-Database/39/right/tingcyr4.bmp
/kaggle/input/MMU-Iris-Database/8/left/eugenehol2.bmp
/kaggle/input/MMU-Iris-Database/8/left/eugenehol5.bmp
/kaggle/input/MMU-Iris-Database/8/left/eugenehol4.bmp
/kaggle/input/MMU-Iris-Database/8/left/eugenehol1.bmp
/kaggle/input/MMU-Iris-Database/8/left/eugenehol3.bmp
/kaggle/input/MMU-Iris-Database/8/right/eugenehor4.bmp
/kaggle/input/MMU-Iris-Database/8/right/eugenehor3.bmp
/kaggle/input/MMU-Iris-Database/8/right/eugenehor5.bmp
/kaggle/input/MMU-Iris-Database/8/right/eugenehor1.bmp
/kaggle/input/MMU-Iris-Database/8/right/eugenehor2.bmp
/kaggle/input/MMU-Iris-Database/36/left/tanwnl2.bmp
/kaggle/input/MMU-Iris-Database/36/left/tanwnl1.bmp
/kaggle/input/MMU-Iris-Database/36/left/tanwnl5.bmp
/kaggle/input/MMU-Iris-Database/36/left/tanwnl4.bmp
/kaggle/input/MMU-Iris-Database/36/left/tanwnl3.bmp
/kaggle/input/MMU-Iris-Database/36/right/tanwnr2.bmp
/kaggle/input/MMU-Iris-Database/36/right/tanwnr3.bmp
/kaggle/input/MMU-Iris-Database/36/right/tanwnr4.bmp
/kaggle/input/MMU-Iris-Database/36/right/tanwnr5.bmp
/kaggle/input/MMU-Iris-Database/36/right/tanwnr1.bmp
/kaggle/input/MMU-Iris-Database/25/left/nkll1.bmp
/kaggle/input/MMU-Iris-Database/25/left/nkll4.bmp
/kaggle/input/MMU-Iris-Database/25/left/nkll3.bmp
/kaggle/input/MMU-Iris-Database/25/left/nkll5.bmp
/kaggle/input/MMU-Iris-Database/25/left/nkll2.bmp
/kaggle/input/MMU-Iris-Database/25/right/nklr5.bmp
/kaggle/input/MMU-Iris-Database/25/right/nklr1.bmp
/kaggle/input/MMU-Iris-Database/25/right/nklr2.bmp
/kaggle/input/MMU-Iris-Database/25/right/nklr4.bmp
/kaggle/input/MMU-Iris-Database/25/right/nklr3.bmp
/kaggle/input/MMU-Iris-Database/3/left/chingycl3.bmp
/kaggle/input/MMU-Iris-Database/3/left/chingycl1.bmp
/kaggle/input/MMU-Iris-Database/3/left/chingycl2.bmp
/kaggle/input/MMU-Iris-Database/3/left/chingycl5.bmp
/kaggle/input/MMU-Iris-Database/3/left/chingycl4.bmp
/kaggle/input/MMU-Iris-Database/3/right/chingycr2.bmp
/kaggle/input/MMU-Iris-Database/3/right/chingycr4.bmp
/kaggle/input/MMU-Iris-Database/3/right/chingycr3.bmp
/kaggle/input/MMU-Iris-Database/3/right/chingycr1.bmp
/kaggle/input/MMU-Iris-Database/3/right/chingycr5.bmp
/kaggle/input/MMU-Iris-Database/2/left/bryanl5.bmp
/kaggle/input/MMU-Iris-Database/2/left/bryanl1.bmp
/kaggle/input/MMU-Iris-Database/2/left/bryanl2.bmp
/kaggle/input/MMU-Iris-Database/2/left/bryanl3.bmp
/kaggle/input/MMU-Iris-Database/2/left/bryanl4.bmp
/kaggle/input/MMU-Iris-Database/2/right/bryanr2.bmp
/kaggle/input/MMU-Iris-Database/2/right/bryanr5.bmp
/kaggle/input/MMU-Iris-Database/2/right/bryanr1.bmp
/kaggle/input/MMU-Iris-Database/2/right/bryanr4.bmp
/kaggle/input/MMU-Iris-Database/2/right/bryanr3.bmp
/kaggle/input/MMU-Iris-Database/10/left/fional3.bmp
/kaggle/input/MMU-Iris-Database/10/left/fional4.bmp
/kaggle/input/MMU-Iris-Database/10/left/Thumbs.db
/kaggle/input/MMU-Iris-Database/10/left/fional5.bmp
/kaggle/input/MMU-Iris-Database/10/left/fional2.bmp
/kaggle/input/MMU-Iris-Database/10/left/fional1.bmp
/kaggle/input/MMU-Iris-Database/10/right/fionar5.bmp
/kaggle/input/MMU-Iris-Database/10/right/fionar3.bmp
/kaggle/input/MMU-Iris-Database/10/right/fionar1.bmp
/kaggle/input/MMU-Iris-Database/10/right/fionar4.bmp
/kaggle/input/MMU-Iris-Database/10/right/fionar2.bmp
/kaggle/input/MMU-Iris-Database/41/left/vimalal5.bmp
/kaggle/input/MMU-Iris-Database/41/left/vimalal4.bmp
/kaggle/input/MMU-Iris-Database/41/left/vimalal2.bmp
/kaggle/input/MMU-Iris-Database/41/left/vimalal3.bmp
/kaggle/input/MMU-Iris-Database/41/left/vimalal1.bmp
/kaggle/input/MMU-Iris-Database/41/right/vimalar4.bmp
/kaggle/input/MMU-Iris-Database/41/right/vimalar5.bmp
/kaggle/input/MMU-Iris-Database/41/right/vimalar1.bmp
/kaggle/input/MMU-Iris-Database/41/right/vimalar3.bmp
/kaggle/input/MMU-Iris-Database/41/right/vimalar2.bmp
/kaggle/input/MMU-Iris-Database/6/left/christinel4.bmp
/kaggle/input/MMU-Iris-Database/6/left/christinel3.bmp
/kaggle/input/MMU-Iris-Database/6/left/christinel5.bmp
/kaggle/input/MMU-Iris-Database/6/left/christinel1.bmp
/kaggle/input/MMU-Iris-Database/6/left/christinel2.bmp
/kaggle/input/MMU-Iris-Database/6/right/christiner5.bmp
/kaggle/input/MMU-Iris-Database/6/right/christiner2.bmp
/kaggle/input/MMU-Iris-Database/6/right/christiner3.bmp
/kaggle/input/MMU-Iris-Database/6/right/christiner4.bmp
/kaggle/input/MMU-Iris-Database/6/right/christiner1.bmp
/kaggle/input/MMU-Iris-Database/24/left/ngkokwhyl3.bmp
/kaggle/input/MMU-Iris-Database/24/left/ngkokwhyl2.bmp
/kaggle/input/MMU-Iris-Database/24/left/ngkokwhyl4.bmp
/kaggle/input/MMU-Iris-Database/24/left/ngkokwhyl5.bmp
/kaggle/input/MMU-Iris-Database/24/left/ngkokwhyl1.bmp
/kaggle/input/MMU-Iris-Database/24/right/ngkokwhyr5.bmp
/kaggle/input/MMU-Iris-Database/24/right/ngkokwhyr2.bmp
/kaggle/input/MMU-Iris-Database/24/right/ngkokwhyr4.bmp
/kaggle/input/MMU-Iris-Database/24/right/ngkokwhyr3.bmp
/kaggle/input/MMU-Iris-Database/24/right/ngkokwhyr1.bmp
/kaggle/input/MMU-Iris-Database/13/left/lecl3.bmp
/kaggle/input/MMU-Iris-Database/13/left/lecl4.bmp
/kaggle/input/MMU-Iris-Database/13/left/lecl5.bmp
/kaggle/input/MMU-Iris-Database/13/left/lecl2.bmp
/kaggle/input/MMU-Iris-Database/13/left/lec_1.bmp
/kaggle/input/MMU-Iris-Database/13/right/lecr1.bmp
/kaggle/input/MMU-Iris-Database/13/right/lecr4.bmp
/kaggle/input/MMU-Iris-Database/13/right/lecr2.bmp
/kaggle/input/MMU-Iris-Database/13/right/lecr3.bmp
/kaggle/input/MMU-Iris-Database/13/right/lecr5.bmp
/kaggle/input/MMU-Iris-Database/17/left/lpjl4.bmp
/kaggle/input/MMU-Iris-Database/17/left/lpjl1.bmp
/kaggle/input/MMU-Iris-Database/17/left/lpjl3.bmp
/kaggle/input/MMU-Iris-Database/17/left/lpjl2.bmp
/kaggle/input/MMU-Iris-Database/17/left/lpjl5.bmp
/kaggle/input/MMU-Iris-Database/17/right/lpjr1.bmp
/kaggle/input/MMU-Iris-Database/17/right/lpjr3.bmp
/kaggle/input/MMU-Iris-Database/17/right/lpjr5.bmp
/kaggle/input/MMU-Iris-Database/17/right/lpjr2.bmp
/kaggle/input/MMU-Iris-Database/17/right/lpjr4.bmp
/kaggle/input/MMU-Iris-Database/14/left/liujwl2.bmp
/kaggle/input/MMU-Iris-Database/14/left/liujwl5.bmp
/kaggle/input/MMU-Iris-Database/14/left/liujwl1.bmp
/kaggle/input/MMU-Iris-Database/14/left/liujwl3.bmp
/kaggle/input/MMU-Iris-Database/14/left/liujwl4.bmp
/kaggle/input/MMU-Iris-Database/14/right/liujwr5.bmp
/kaggle/input/MMU-Iris-Database/14/right/liujwr3.bmp
/kaggle/input/MMU-Iris-Database/14/right/liujwr1.bmp
/kaggle/input/MMU-Iris-Database/14/right/liujwr2.bmp
/kaggle/input/MMU-Iris-Database/14/right/liujwr4.bmp
/kaggle/input/MMU-Iris-Database/27/left/norsuhaidahl2.bmp
/kaggle/input/MMU-Iris-Database/27/left/norsuhaidahl3.bmp
/kaggle/input/MMU-Iris-Database/27/left/norsuhaidahl4.bmp
/kaggle/input/MMU-Iris-Database/27/left/norsuhaidahl5.bmp
/kaggle/input/MMU-Iris-Database/27/left/norsuhaidahl1.bmp
/kaggle/input/MMU-Iris-Database/27/right/norsuhaidahr2.bmp
/kaggle/input/MMU-Iris-Database/27/right/norsuhaidahr4.bmp
/kaggle/input/MMU-Iris-Database/27/right/norsuhaidahr5.bmp
/kaggle/input/MMU-Iris-Database/27/right/norsuhaidahr3.bmp
/kaggle/input/MMU-Iris-Database/27/right/norsuhaidahr1.bmp
/kaggle/input/MMU-Iris-Database/44/left/yannl2.bmp
/kaggle/input/MMU-Iris-Database/44/left/yannl3.bmp
/kaggle/input/MMU-Iris-Database/44/left/yannl1.bmp
/kaggle/input/MMU-Iris-Database/44/left/yannl5.bmp
/kaggle/input/MMU-Iris-Database/44/left/yannl4.bmp
/kaggle/input/MMU-Iris-Database/44/right/yannr5.bmp
/kaggle/input/MMU-Iris-Database/44/right/yannr1.bmp
/kaggle/input/MMU-Iris-Database/44/right/yannr4.bmp
/kaggle/input/MMU-Iris-Database/44/right/yannr3.bmp
/kaggle/input/MMU-Iris-Database/44/right/yannr2.bmp
/kaggle/input/MMU-Iris-Database/11/left/hockl4.bmp
/kaggle/input/MMU-Iris-Database/11/left/hockl2.bmp
/kaggle/input/MMU-Iris-Database/11/left/hockl3.bmp
/kaggle/input/MMU-Iris-Database/11/left/hockl5.bmp
/kaggle/input/MMU-Iris-Database/11/left/hockl1.bmp
/kaggle/input/MMU-Iris-Database/11/right/hockr1.bmp
/kaggle/input/MMU-Iris-Database/11/right/hockr3.bmp
/kaggle/input/MMU-Iris-Database/11/right/hockr4.bmp
/kaggle/input/MMU-Iris-Database/11/right/hockr2.bmp
/kaggle/input/MMU-Iris-Database/11/right/hockr5.bmp
/kaggle/input/MMU-Iris-Database/18/left/mahskl2.bmp
/kaggle/input/MMU-Iris-Database/18/left/mahskl3.bmp
/kaggle/input/MMU-Iris-Database/18/left/mahskl5.bmp
/kaggle/input/MMU-Iris-Database/18/left/mahskl4.bmp
/kaggle/input/MMU-Iris-Database/18/left/mahskl1.bmp
/kaggle/input/MMU-Iris-Database/18/right/mahskr4.bmp
/kaggle/input/MMU-Iris-Database/18/right/mahskr5.bmp
/kaggle/input/MMU-Iris-Database/18/right/mahskr2.bmp
/kaggle/input/MMU-Iris-Database/18/right/mahskr3.bmp
/kaggle/input/MMU-Iris-Database/18/right/mahskr1.bmp
/kaggle/input/MMU-Iris-Database/9/left/fatmal4.bmp
/kaggle/input/MMU-Iris-Database/9/left/fatmal3.bmp
/kaggle/input/MMU-Iris-Database/9/left/fatmal5.bmp
/kaggle/input/MMU-Iris-Database/9/left/fatmal2.bmp
/kaggle/input/MMU-Iris-Database/9/left/fatmal1.bmp
/kaggle/input/MMU-Iris-Database/9/right/fatmar3.bmp
/kaggle/input/MMU-Iris-Database/9/right/fatmar2.bmp
/kaggle/input/MMU-Iris-Database/9/right/fatmar4.bmp
/kaggle/input/MMU-Iris-Database/9/right/fatmar1.bmp
/kaggle/input/MMU-Iris-Database/9/right/fatmar5.bmp
/kaggle/input/MMU-Iris-Database/43/left/winl4.bmp
/kaggle/input/MMU-Iris-Database/43/left/winl2.bmp
/kaggle/input/MMU-Iris-Database/43/left/winl5.bmp
/kaggle/input/MMU-Iris-Database/43/left/winl3.bmp
/kaggle/input/MMU-Iris-Database/43/left/winl1.bmp
/kaggle/input/MMU-Iris-Database/43/right/winr3.bmp
/kaggle/input/MMU-Iris-Database/43/right/winr4.bmp
/kaggle/input/MMU-Iris-Database/43/right/winr1.bmp
/kaggle/input/MMU-Iris-Database/43/right/winr5.bmp
/kaggle/input/MMU-Iris-Database/43/right/winr2.bmp
/kaggle/input/MMU-Iris-Database/20/left/masl1.bmp
/kaggle/input/MMU-Iris-Database/20/left/masl4.bmp
/kaggle/input/MMU-Iris-Database/20/left/masl5.bmp
/kaggle/input/MMU-Iris-Database/20/left/masl2.bmp
/kaggle/input/MMU-Iris-Database/20/left/masl3.bmp
/kaggle/input/MMU-Iris-Database/20/right/masr4.bmp
/kaggle/input/MMU-Iris-Database/20/right/masr2.bmp
/kaggle/input/MMU-Iris-Database/20/right/masr5.bmp
/kaggle/input/MMU-Iris-Database/20/right/masr1.bmp
/kaggle/input/MMU-Iris-Database/20/right/masr3.bmp
/kaggle/input/MMU-Iris-Database/5/left/chongpkl3.bmp
/kaggle/input/MMU-Iris-Database/5/left/chongpkl4.bmp
/kaggle/input/MMU-Iris-Database/5/left/chongpkl5.bmp
/kaggle/input/MMU-Iris-Database/5/left/chongpkl1.bmp
/kaggle/input/MMU-Iris-Database/5/left/chongpkl2.bmp
/kaggle/input/MMU-Iris-Database/5/right/chongpkr5.bmp
/kaggle/input/MMU-Iris-Database/5/right/chongpkr1.bmp
/kaggle/input/MMU-Iris-Database/5/right/chongpkr4.bmp
/kaggle/input/MMU-Iris-Database/5/right/chongpkr3.bmp
/kaggle/input/MMU-Iris-Database/5/right/chongpkr2.bmp
/kaggle/input/MMU-Iris-Database/35/left/suzailil5.bmp
/kaggle/input/MMU-Iris-Database/35/left/suzailil1.bmp
/kaggle/input/MMU-Iris-Database/35/left/suzailil3.bmp
/kaggle/input/MMU-Iris-Database/35/left/suzailil4.bmp
/kaggle/input/MMU-Iris-Database/35/left/suzailil2.bmp
/kaggle/input/MMU-Iris-Database/35/right/suzailir1.bmp
/kaggle/input/MMU-Iris-Database/35/right/suzailir2.bmp
/kaggle/input/MMU-Iris-Database/35/right/suzailir3.bmp
/kaggle/input/MMU-Iris-Database/35/right/suzailir4.bmp
/kaggle/input/MMU-Iris-Database/35/right/suzailir5.bmp
/kaggle/input/MMU-Iris-Database/34/left/sitil2.bmp
/kaggle/input/MMU-Iris-Database/34/left/sitil5.bmp
/kaggle/input/MMU-Iris-Database/34/left/sitil4.bmp
/kaggle/input/MMU-Iris-Database/34/left/sitil1.bmp
/kaggle/input/MMU-Iris-Database/34/left/sitil3.bmp
/kaggle/input/MMU-Iris-Database/34/right/sitir4.bmp
/kaggle/input/MMU-Iris-Database/34/right/sitir3.bmp
/kaggle/input/MMU-Iris-Database/34/right/sitir2.bmp
/kaggle/input/MMU-Iris-Database/34/right/sitir1.bmp
/kaggle/input/MMU-Iris-Database/34/right/sitir5.bmp
/kaggle/input/MMU-Iris-Database/45/left/zaridahl3.bmp
/kaggle/input/MMU-Iris-Database/45/left/zaridahl5.bmp
/kaggle/input/MMU-Iris-Database/45/left/zaridahl1.bmp
/kaggle/input/MMU-Iris-Database/45/left/zaridahl2.bmp
/kaggle/input/MMU-Iris-Database/45/left/zaridahl4.bmp
/kaggle/input/MMU-Iris-Database/45/right/zaridahr3.bmp
/kaggle/input/MMU-Iris-Database/45/right/zaridahr1.bmp
/kaggle/input/MMU-Iris-Database/45/right/zaridahr5.bmp
/kaggle/input/MMU-Iris-Database/45/right/zaridahr2.bmp
/kaggle/input/MMU-Iris-Database/45/right/zaridahr4.bmp
/kaggle/input/MMU-Iris-Database/32/left/salal1.bmp
/kaggle/input/MMU-Iris-Database/32/left/salal2.bmp
/kaggle/input/MMU-Iris-Database/32/left/salal5.bmp
/kaggle/input/MMU-Iris-Database/32/left/salal4.bmp
/kaggle/input/MMU-Iris-Database/32/left/salal3.bmp
/kaggle/input/MMU-Iris-Database/32/right/salar1.bmp
/kaggle/input/MMU-Iris-Database/32/right/salar3.bmp
/kaggle/input/MMU-Iris-Database/32/right/salar2.bmp
/kaggle/input/MMU-Iris-Database/32/right/salar5.bmp
/kaggle/input/MMU-Iris-Database/32/right/salar4.bmp
/kaggle/input/MMU-Iris-Database/38/left/tickl1.bmp
/kaggle/input/MMU-Iris-Database/38/left/tickl5.bmp
/kaggle/input/MMU-Iris-Database/38/left/tickl2.bmp
/kaggle/input/MMU-Iris-Database/38/left/tickl3.bmp
/kaggle/input/MMU-Iris-Database/38/left/tickl4.bmp
/kaggle/input/MMU-Iris-Database/38/right/tickr3.bmp
/kaggle/input/MMU-Iris-Database/38/right/tickr1.bmp
/kaggle/input/MMU-Iris-Database/38/right/tickr5.bmp
/kaggle/input/MMU-Iris-Database/38/right/tickr2.bmp
/kaggle/input/MMU-Iris-Database/38/right/tickr4.bmp
/kaggle/input/MMU-Iris-Database/22/left/mimil2.bmp
/kaggle/input/MMU-Iris-Database/22/left/mimil4.bmp
/kaggle/input/MMU-Iris-Database/22/left/mimil5.bmp
/kaggle/input/MMU-Iris-Database/22/left/mimil1.bmp
/kaggle/input/MMU-Iris-Database/22/left/mimil3.bmp
/kaggle/input/MMU-Iris-Database/22/right/mimir1.bmp
/kaggle/input/MMU-Iris-Database/22/right/mimir5.bmp
/kaggle/input/MMU-Iris-Database/22/right/mimir2.bmp
/kaggle/input/MMU-Iris-Database/22/right/mimir3.bmp
/kaggle/input/MMU-Iris-Database/22/right/mimir4.bmp
/kaggle/input/MMU-Iris-Database/31/left/roslil3.bmp
/kaggle/input/MMU-Iris-Database/31/left/roslil2.bmp
/kaggle/input/MMU-Iris-Database/31/left/roslil5.bmp
/kaggle/input/MMU-Iris-Database/31/left/roslil1.bmp
/kaggle/input/MMU-Iris-Database/31/left/roslil4.bmp
/kaggle/input/MMU-Iris-Database/31/right/roslir1.bmp
/kaggle/input/MMU-Iris-Database/31/right/roslir2.bmp
/kaggle/input/MMU-Iris-Database/31/right/roslir4.bmp
/kaggle/input/MMU-Iris-Database/31/right/roslir5.bmp
/kaggle/input/MMU-Iris-Database/31/right/roslir3.bmp
/kaggle/input/MMU-Iris-Database/46/left/zulaikahl1.bmp
/kaggle/input/MMU-Iris-Database/46/left/zulaikahl4.bmp
/kaggle/input/MMU-Iris-Database/46/left/zulaikahl3.bmp
/kaggle/input/MMU-Iris-Database/46/left/Thumbs.db
/kaggle/input/MMU-Iris-Database/46/left/zulaikahl5.bmp
/kaggle/input/MMU-Iris-Database/46/left/zulaikahl2.bmp
/kaggle/input/MMU-Iris-Database/46/right/zulaikahr1.bmp
/kaggle/input/MMU-Iris-Database/46/right/zulaikahr3.bmp
/kaggle/input/MMU-Iris-Database/46/right/zulaikahr2.bmp
/kaggle/input/MMU-Iris-Database/46/right/zulaikahr4.bmp
/kaggle/input/MMU-Iris-Database/46/right/zulaikahr5.bmp
/kaggle/input/MMU-Iris-Database/30/left/philipl1.bmp
/kaggle/input/MMU-Iris-Database/30/left/philipl4.bmp
/kaggle/input/MMU-Iris-Database/30/left/philipl2.bmp
/kaggle/input/MMU-Iris-Database/30/left/philipl5.bmp
/kaggle/input/MMU-Iris-Database/30/left/philipl3.bmp
/kaggle/input/MMU-Iris-Database/30/right/philipr1.bmp
/kaggle/input/MMU-Iris-Database/30/right/philipr4.bmp
/kaggle/input/MMU-Iris-Database/30/right/philipr5.bmp
/kaggle/input/MMU-Iris-Database/30/right/philipr3.bmp
/kaggle/input/MMU-Iris-Database/30/right/philipr2.bmp
/kaggle/input/MMU-Iris-Database/40/left/tonghll2.bmp
/kaggle/input/MMU-Iris-Database/40/left/tonghll5.bmp
/kaggle/input/MMU-Iris-Database/40/left/tonghll3.bmp
/kaggle/input/MMU-Iris-Database/40/left/tonghll4.bmp
/kaggle/input/MMU-Iris-Database/40/left/tonghll1.bmp
/kaggle/input/MMU-Iris-Database/40/right/tonghlr1.bmp
/kaggle/input/MMU-Iris-Database/40/right/tonghlr4.bmp
/kaggle/input/MMU-Iris-Database/40/right/tonghlr2.bmp
/kaggle/input/MMU-Iris-Database/40/right/tonghlr5.bmp
/kaggle/input/MMU-Iris-Database/40/right/tonghlr3.bmp
/kaggle/input/MMU-Iris-Database/26/left/norazal2.bmp
/kaggle/input/MMU-Iris-Database/26/left/norazal4.bmp
/kaggle/input/MMU-Iris-Database/26/left/norazal1.bmp
/kaggle/input/MMU-Iris-Database/26/left/norazal3.bmp
/kaggle/input/MMU-Iris-Database/26/left/norazal5.bmp
/kaggle/input/MMU-Iris-Database/26/right/norazar3.bmp
/kaggle/input/MMU-Iris-Database/26/right/norazar1.bmp
/kaggle/input/MMU-Iris-Database/26/right/norazar5.bmp
/kaggle/input/MMU-Iris-Database/26/right/norazar2.bmp
/kaggle/input/MMU-Iris-Database/26/right/norazar4.bmp
/kaggle/input/MMU-Iris-Database/15/left/lokel1.bmp
/kaggle/input/MMU-Iris-Database/15/left/lokel5.bmp
/kaggle/input/MMU-Iris-Database/15/left/lokel3.bmp
/kaggle/input/MMU-Iris-Database/15/left/lokel2.bmp
/kaggle/input/MMU-Iris-Database/15/left/lokel4.bmp
/kaggle/input/MMU-Iris-Database/15/right/loker5.bmp
/kaggle/input/MMU-Iris-Database/15/right/loker2.bmp
/kaggle/input/MMU-Iris-Database/15/right/loker4.bmp
/kaggle/input/MMU-Iris-Database/15/right/loker3.bmp
/kaggle/input/MMU-Iris-Database/15/right/loker1.bmp
/kaggle/input/MMU-Iris-Database/16/left/lowyfl1.bmp
/kaggle/input/MMU-Iris-Database/16/left/lowyfl2.bmp
/kaggle/input/MMU-Iris-Database/16/left/lowyfl5.bmp
/kaggle/input/MMU-Iris-Database/16/left/lowyfl4.bmp
/kaggle/input/MMU-Iris-Database/16/left/lowyfl3.bmp
/kaggle/input/MMU-Iris-Database/16/right/lowyfr5.bmp
/kaggle/input/MMU-Iris-Database/16/right/lowyfr4.bmp
/kaggle/input/MMU-Iris-Database/16/right/lowyfr2.bmp
/kaggle/input/MMU-Iris-Database/16/right/lowyfr3.bmp
/kaggle/input/MMU-Iris-Database/16/right/lowyfr1.bmp
/kaggle/input/MMU-Iris-Database/7/left/chualsl2.bmp
/kaggle/input/MMU-Iris-Database/7/left/chualsl4.bmp
/kaggle/input/MMU-Iris-Database/7/left/Thumbs.db
/kaggle/input/MMU-Iris-Database/7/left/chualsl1.bmp
/kaggle/input/MMU-Iris-Database/7/left/chualsl3.bmp
/kaggle/input/MMU-Iris-Database/7/left/chualsl5.bmp
/kaggle/input/MMU-Iris-Database/7/right/chualsr2.bmp
/kaggle/input/MMU-Iris-Database/7/right/chualsr3.bmp
/kaggle/input/MMU-Iris-Database/7/right/chualsr4.bmp
/kaggle/input/MMU-Iris-Database/7/right/chualsr5.bmp
/kaggle/input/MMU-Iris-Database/7/right/chualsr1.bmp
/kaggle/input/MMU-Iris-Database/37/left/thomasl1.bmp
/kaggle/input/MMU-Iris-Database/37/left/thomasl3.bmp
/kaggle/input/MMU-Iris-Database/37/left/Thumbs.db
/kaggle/input/MMU-Iris-Database/37/left/thomasl2.bmp
/kaggle/input/MMU-Iris-Database/37/left/thomasl5.bmp
/kaggle/input/MMU-Iris-Database/37/left/thomasl4.bmp
/kaggle/input/MMU-Iris-Database/37/right/thomasr5.bmp
/kaggle/input/MMU-Iris-Database/37/right/thomasr1.bmp
/kaggle/input/MMU-Iris-Database/37/right/thomasr2.bmp
/kaggle/input/MMU-Iris-Database/37/right/thomasr3.bmp
/kaggle/input/MMU-Iris-Database/37/right/thomasr4.bmp
/kaggle/input/MMU-Iris-Database/21/left/mazwanl1.bmp
/kaggle/input/MMU-Iris-Database/21/left/mazwanl5.bmp
/kaggle/input/MMU-Iris-Database/21/left/mazwanl3.bmp
/kaggle/input/MMU-Iris-Database/21/left/mazwanl2.bmp
/kaggle/input/MMU-Iris-Database/21/left/mazwanl4.bmp
/kaggle/input/MMU-Iris-Database/21/right/mazwanr5.bmp
/kaggle/input/MMU-Iris-Database/21/right/mazwanr2.bmp
/kaggle/input/MMU-Iris-Database/21/right/mazwanr1.bmp
/kaggle/input/MMU-Iris-Database/21/right/mazwanr3.bmp
/kaggle/input/MMU-Iris-Database/21/right/mazwanr4.bmp
/kaggle/input/MMU-Iris-Database/29/left/pcll4.bmp
/kaggle/input/MMU-Iris-Database/29/left/pcll1.bmp
/kaggle/input/MMU-Iris-Database/29/left/pcll5.bmp
/kaggle/input/MMU-Iris-Database/29/left/pcll2.bmp
/kaggle/input/MMU-Iris-Database/29/left/pcll3.bmp
/kaggle/input/MMU-Iris-Database/29/right/pclr2.bmp
/kaggle/input/MMU-Iris-Database/29/right/pclr3.bmp
/kaggle/input/MMU-Iris-Database/29/right/pclr5.bmp
/kaggle/input/MMU-Iris-Database/29/right/pclr1.bmp
/kaggle/input/MMU-Iris-Database/29/right/pclr4.bmp
/kaggle/input/MMU-Iris-Database/23/left/minglil5.bmp
/kaggle/input/MMU-Iris-Database/23/left/minglil3.bmp
/kaggle/input/MMU-Iris-Database/23/left/minglil1.bmp
/kaggle/input/MMU-Iris-Database/23/left/minglil4.bmp
/kaggle/input/MMU-Iris-Database/23/left/minglil2.bmp
/kaggle/input/MMU-Iris-Database/23/right/minglir2.bmp
/kaggle/input/MMU-Iris-Database/23/right/minglir1.bmp
/kaggle/input/MMU-Iris-Database/23/right/minglir4.bmp
/kaggle/input/MMU-Iris-Database/23/right/minglir3.bmp
/kaggle/input/MMU-Iris-Database/23/right/minglir5.bmp
/kaggle/input/MMU-Iris-Database/42/left/weecml1.bmp
/kaggle/input/MMU-Iris-Database/42/left/weecml4.bmp
/kaggle/input/MMU-Iris-Database/42/left/Thumbs.db
/kaggle/input/MMU-Iris-Database/42/left/weecml2.bmp
/kaggle/input/MMU-Iris-Database/42/left/weecml5.bmp
/kaggle/input/MMU-Iris-Database/42/left/weecml3.bmp
/kaggle/input/MMU-Iris-Database/42/right/weecmr4.bmp
/kaggle/input/MMU-Iris-Database/42/right/weecmr2.bmp
/kaggle/input/MMU-Iris-Database/42/right/weecmr5.bmp
/kaggle/input/MMU-Iris-Database/42/right/weecmr1.bmp
/kaggle/input/MMU-Iris-Database/42/right/weecmr3.bmp

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = (nCol + nGraphPerRow - 1) / nGraphPerRow
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
# Correlation matrix
def plotCorrelationMatrix(df, graphWidth):
    filename = df.dataframeName
    df = df.dropna('columns') # drop columns with NaN
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()

# %%
# Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()
